# %%
import pandas as pd

# %%
data = pd.read_csv('People.csv')

# %%
# initial list of people
data
# Out:
#                  Name                                              Email  Age
# 0     Armando Leonard                scelerisque.neque@Nullaegetmetus.ca   32
# 1      Colette Prince                    vitae.odio@dapibusgravida.co.uk   23
# 2           Oleg Chen                                       at@sit.co.uk   18
# 3       Camilla Boyer                      Quisque@metusurnaconvallis.ca   18
# 4         Zorita Dyer             Nam.porttitor.scelerisque@dolorsit.org   18
# 5      Holly Valencia                      sem.magna.nec@Suspendisse.com   18
# 6     Chastity Berger                        sed.tortor@vitaepurus.co.uk   18
# 7         Ronan Allen                   consectetuer.cursus@dolorquam.ca   28
# 8        Wylie Hopper                          pharetra@erosturpis.co.uk   15
# 9      Carl Frederick                     ornare.lectus@imperdietnon.org   15
# 10      Conan Shelton                    velit.justo.nec@urnaNuncquis.ca    6
# ...

# %%
data_18 = data.query('Age >= 18')
# this filters the people who all are eligible for voting(people who have age more than or equal to 18)

# %%
data_18
# Out:
#                 Name                                              Email  Age
# 0    Armando Leonard                scelerisque.neque@Nullaegetmetus.ca   32
# 1     Colette Prince                    vitae.odio@dapibusgravida.co.uk   23
# 2          Oleg Chen                                       at@sit.co.uk   18
# 3      Camilla Boyer                      Quisque@metusurnaconvallis.ca   18
# 4        Zorita Dyer             Nam.porttitor.scelerisque@dolorsit.org   18
# 5     Holly Valencia                      sem.magna.nec@Suspendisse.com   18
# 6    Chastity Berger                        sed.tortor@vitaepurus.co.uk   18
# 7        Ronan Allen                   consectetuer.cursus@dolorquam.ca   28
# 11  Simon Harrington                      non.justo.Proin@ridiculus.edu   18
# 13    Derek Erickson                         Aliquam.nec@auctorquis.com   18
# 14     Harding Hurst                    Praesent.eu.nulla@eratneque.net   18
# ...

# %%
data_18.to_csv('People_eligible.csv')
